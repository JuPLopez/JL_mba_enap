# %% [markdown]
# ## A. Importando bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# ## I. BASE DO PROFESSOR = IDEB

# %%
df_ED = pd.read_excel('https://github.com/alexlopespereira/mba_enap/raw/main/data/originais/ideb/ideb_municipios2017.xlsx', skipfooter=3, skiprows= 9, na_values='-')
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11262 entries, 0 to 11261
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SG_UF         11262 non-null  object
#  1   COD_MUN       11262 non-null  int64
#  2   NO_MUNICIPIO  11262 non-null  object
#  3   REDE          11262 non-null  object
#  4   TAP_MED       11259 non-null  float64
#  5   TAP_M01       11217 non-null  float64
#  6   TAP_M02       11244 non-null  float64
#  7   TAP_M03       11253 non-null  float64
#  8   TAP_M04       1974 non-null   float64
#  9   TAP_MNS       783 non-null    float64
#  10  P12           11256 non-null  float64
#  11  PB12_MAT17    11262 non-null  object
#  12  PB12_PORT17   11262 non-null  object
#  13  PAD12_17      10919 non-null  float64
#  14  IDEB12_17     10914 non-null  float64
#  15  PROJEM_2019   10914 non-null  float64
#  16  PROJEM_2021   10914 non-null  float64
# ...

# %% [markdown]
# ## B. Lendo planilhas (abas) do excel

# %% [markdown]
# ## C. Valores únicos de uma coluna
#
# df[column_name].unique().tolist()

# %% [markdown]
# ## Contagem de valores únicos de uma coluna
#
# df[column_name].value_counts()

# %%
excel_file = pd.ExcelFile('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/planilha-de-area-atingida-por-fogo-historico-dgeo-3.xlsx')
planilhas = excel_file.sheet_names
print("Planilhas encontradas:")
for planilha in planilhas:
    print(f"- {planilha}")
# Out:
# Planilhas encontradas:
# - 2024
# - 2023
# - 2022
# - 2021
# - 2020
# - 2019
# - 2018
# - 2017
# - 2016
# - 2015
# - 2014
# - 2013
# - 2012
# - 2011
# - 2010
# - 2008
# - 2007

# %% [markdown]
# ## II. BASE DESMATAMENTO

# %%
df_desmat = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/tabela_de_desmatamento_ucs_atualizado_prodes-2023(1).xlsx', skiprows= 1, skipfooter=1)
df_desmat.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cnuc                    132 non-null    object
#  1   unidade de conservação  132 non-null    object
#  2   área_ha_uc              132 non-null    float64
#  3   Até 2007                132 non-null    float64
#  4   2008                    132 non-null    float64
#  5   2009                    132 non-null    float64
#  6   2010                    132 non-null    float64
#  7   2011                    132 non-null    float64
#  8   2012                    132 non-null    float64
#  9   2013                    132 non-null    float64
#  10  2014                    132 non-null    float64
#  11  2015                    132 non-null    float64
#  12  2016                    132 non-null    float64
#  13  2017                    132 non-null    float64
# ...

# %% [markdown]
# ## III. BASE QUEIMADAS

# %%
df_queimada = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/planilha-de-area-atingida-por-fogo-historico-dgeo-3.xlsx', skipfooter=1)
df_queimada.tail()
# Out:
#               Unidade de Conservação   \
# 88                RESEX Lago do Cedro
# 89                    RESEX Rio Xingu
# 90             RESEX Tapajós-Arapiuns
# 91  REVIS das Veredas do Oeste Baiano
# 92         REVIS dos Campos de Palmas
#
#                                                   NGI                   GR  \
# 88  Núcleo de Gestão Integrada - ICMBio Meandros d...  GR 3 - CENTRO-OESTE
# 89  Núcleo de Gestão Integrada - ICMBio Terra do Meio         GR 1 - NORTE
# 90                                                  -         GR 1 - NORTE
# 91         Núcleo de Gestão Integrada - ICMBio Mambaí  GR 3 - CENTRO-OESTE
# 92         Núcleo de Gestão Integrada - ICMBio Palmas           GR 5 - SUL
#
#     Incêndio (ha)  Queima prescrita (ha)  Queima controlada (ha)  Aceiro (ha)  \
# 88     436.190776               0.000000                0.000000          0.0
# 89      29.377423               0.000000                0.000000          0.0
# ...

# %% [markdown]
# ## IV. BASE CNUC

# %%
df_cnuc = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/ucs_aprovadas_exportado_em__19_02_2025_%C3%A0s_19h_24m_09s.xlsx')
df_cnuc.head()
# Out:
#                                           Nome da UC Esfera Administrativa  \
# 0  RESERVA PARTICULAR DO PATRIMÔNIO NATURAL FAZEN...              Estadual
# 1  RESERVA PARTICULAR DO PATRIMÔNIO NATURAL FAZEN...              Estadual
# 2                  FLORESTA ESTADUAL SÃO JUDAS TADEU              Estadual
# 3                    FLORESTA ESTADUAL DO PASSA DOIS              Estadual
# 4  ÁREA DE PROTEÇÃO AMBIENTAL DA NASCENTE DO RIO ...             Municipal
#
#   Sigla Órgão Gestor Situação                      Categorias de Manejo  \
# 0               CPRH    Ativo  Reserva Particular do Patrimônio Natural
# 1               CPRH    Ativo  Reserva Particular do Patrimônio Natural
# 2                IEF    Ativo                                  Floresta
# 3                IAP    Ativo                                  Floresta
# 4             SEMTMA    Ativo                Área de Proteção Ambiental
#
#     Código CNUC
# 0  0000.26.0974
# 1  0000.26.0969
# 2  0000.31.0895
# ...

# %% [markdown]
# ## V. BASE SAMGE

# %%
excel_file = pd.ExcelFile('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/Dados%20do%20SAMGe_completo.xlsx')
planilhas = excel_file.sheet_names
print("Planilhas encontradas:")
for planilha in planilhas:
    print(f"- {planilha}")
# Out:
# Planilhas encontradas:
# - 0 - Atualização
# - 1 - Identificação e Resultados
# - 2 - Recursos e Valores (RV)
# - 3 - Usos
# - 4 - Ações
# - 5 - Ações x Usos
# - 6 - RV x Ações x Usos
# - 7 - Processos Prioritários

# %% [markdown]
# ### SAMGe 1: Identificação e Resultados

# %%
df_samge1 = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/Dados%20do%20SAMGe_completo.xlsx', sheet_name = '1 - Identificação e Resultados')
df_samge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3638 entries, 0 to 3637
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID Entrada                      3638 non-null   int64
#  1   Ano                             3638 non-null   int64
#  2   Esfera Administrativa           3638 non-null   object
#  3   CNUC                            3638 non-null   object
#  4   Nome da UC                      3638 non-null   object
#  5   Gerência Regional/Órgão Gestor  3638 non-null   object
#  6   NGI                             1422 non-null   object
#  7   UF                              3638 non-null   object
#  8   Municípios Abrangidos           3638 non-null   object
#  9   Latitude                        3566 non-null   float64
#  10  Longitude                       3566 non-null   float64
#  11  Quem Preenche                   3627 non-null   object
# ...

# %%
df_samge1["Ano"].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017], dtype=int64)

# %% [markdown]
# ### SAMGe 2: Recursos e Valores

# %%
df_samge2 = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/Dados%20do%20SAMGe_completo.xlsx', sheet_name = '2 - Recursos e Valores (RV)')
df_samge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21395 entries, 0 to 21394
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID Entrada                      21395 non-null  int64
#  1   ID RV                           21395 non-null  int64
#  2   Ano                             21395 non-null  int64
#  3   Esfera Administrativa           21395 non-null  object
#  4   CNUC                            21395 non-null  object
#  5   Nome da UC                      21395 non-null  object
#  6   Gerência Regional/Órgão Gestor  21395 non-null  object
#  7   NGI                             8728 non-null   object
#  8   Classe do Objetivo              21395 non-null  object
#  9   Descrição do Objetivo           21395 non-null  object
#  10  Descrição do RV                 21379 non-null  object
#  11  Tipo do RV                      21395 non-null  object
# ...

# %%
#df_samge2["Classe do Objetivo"].unique()

# %%
#df_samge2["Classe do Objetivo"].value_counts()
df_samge2["Ano"].unique()
# Out:
# array([2023, 2022, 2021, 2020, 2019, 2018, 2017], dtype=int64)

# %% [markdown]
# ### SAMGe 3: USos

# %%
df_samge3 = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/Dados%20do%20SAMGe_completo.xlsx', sheet_name = '3 - Usos')
df_samge3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52443 entries, 0 to 52442
# Data columns (total 34 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   ID Entrada                                                        52443 non-null  int64
#  1   ID Uso                                                            52443 non-null  int64
#  2   Ano                                                               52443 non-null  int64
#  3   Esfera Administrativa                                             52443 non-null  object
#  4   CNUC                                                              52443 non-null  object
#  5   Nome da UC                                                        52443 non-null  object
#  6   Gerência Regional/Órgão Gestor                                    52443 non-null  object
# ...

# %%
df_samge3["Desafio Territorial de Gestão"].unique()
# Out:
# array(['Não', 'Sim'], dtype=object)

# %% [markdown]
# ### SAMGe 4: Ações

# %%
df_samge4 = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/Dados%20do%20SAMGe_completo.xlsx', sheet_name = '4 - Ações')
df_samge4.head()
# Out:
#    ID Entrada  ID Ação   Ano          CNUC       Nome da UC  \
# 0       11009    51327  2023  0000.00.0001  APA ANHATOMIRIM
# 1       11009    51335  2023  0000.00.0001  APA ANHATOMIRIM
# 2       11009    51330  2023  0000.00.0001  APA ANHATOMIRIM
# 3       11009    51761  2023  0000.00.0001  APA ANHATOMIRIM
# 4       11009    51329  2023  0000.00.0001  APA ANHATOMIRIM
#
#   Gerência Regional/Órgão Gestor                   NGI Esfera Administrativa  \
# 0                      GR5 - Sul  ICMBio Florianópolis               Federal
# 1                      GR5 - Sul  ICMBio Florianópolis               Federal
# 2                      GR5 - Sul  ICMBio Florianópolis               Federal
# 3                      GR5 - Sul  ICMBio Florianópolis               Federal
# 4                      GR5 - Sul  ICMBio Florianópolis               Federal
#
#    Média Avaliação Insumos                                           Processo  \
# ...

# %%
# df_samge4["Ação de Manejo"].unique()

# %% [markdown]
# ### SAMGe 5: Ações x Usos

# %%
df_samge5 = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/Dados%20do%20SAMGe_completo.xlsx', sheet_name = '5 - Ações x Usos')
df_samge5.head()
# Out:
#    ID Entrada   Ano Esfera Administrativa          CNUC       Nome da UC  \
# 0       11009  2023               Federal  0000.00.0001  APA ANHATOMIRIM
# 1       11009  2023               Federal  0000.00.0001  APA ANHATOMIRIM
# 2       11009  2023               Federal  0000.00.0001  APA ANHATOMIRIM
# 3       11009  2023               Federal  0000.00.0001  APA ANHATOMIRIM
# 4       11009  2023               Federal  0000.00.0001  APA ANHATOMIRIM
#
#   Gerência Regional/Órgão Gestor                   NGI  ID Uso  \
# 0                      GR5 - Sul  ICMBio Florianópolis   63004
# 1                      GR5 - Sul  ICMBio Florianópolis   63006
# 2                      GR5 - Sul  ICMBio Florianópolis   63006
# 3                      GR5 - Sul  ICMBio Florianópolis   63016
# 4                      GR5 - Sul  ICMBio Florianópolis   63016
#
#                 Uso Genérico  \
# 0    1 - PESQUISA CIENTÍFICA
# 1    1 - PESQUISA CIENTÍFICA
# 2    1 - PESQUISA CIENTÍFICA
# ...

# %% [markdown]
# ### SAMGe 6: RV x Ações x Usos

# %%
df_samge6 = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/Dados%20do%20SAMGe_completo.xlsx', sheet_name = '6 - RV x Ações x Usos')
df_samge6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105202 entries, 0 to 105201
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ID Entrada                      105202 non-null  int64
#  1   Ano                             105202 non-null  int64
#  2   Esfera Administrativa           105202 non-null  object
#  3   CNUC                            105202 non-null  object
#  4   Nome da UC                      105202 non-null  object
#  5   Gerência Regional/Órgão Gestor  105202 non-null  object
#  6   NGI                             44377 non-null   object
#  7   ID RV                           105202 non-null  int64
#  8   Descrição do RV                 105135 non-null  object
#  9   ID Ação                         54059 non-null   float64
#  10  Processo                        54059 non-null   object
#  11  Ação de Manejo                  54059 non-null   object
# ...

# %% [markdown]
# ### SAMGe 7: Processos Prioritários

# %%
df_samge7 = pd.read_excel('https://github.com/JuPLopez/JL_mba_enap/raw/refs/heads/main/Estatistica_Descritiva/Dados%20do%20SAMGe_completo.xlsx', sheet_name = '7 - Processos Prioritários')
df_samge7.head()
# Out:
#    ID Entrada  ID Ação   Ano Esfera Administrativa          CNUC  \
# 0       11009    51326  2023               Federal  0000.00.0001
# 1       11009    51327  2023               Federal  0000.00.0001
# 2       11009    51341  2023               Federal  0000.00.0001
# 3       11009    51330  2023               Federal  0000.00.0001
# 4       11009    51335  2023               Federal  0000.00.0001
#
#         Nome da UC Gerência Regional/Órgão Gestor                   NGI  \
# 0  APA ANHATOMIRIM                      GR5 - Sul  ICMBio Florianópolis
# 1  APA ANHATOMIRIM                      GR5 - Sul  ICMBio Florianópolis
# 2  APA ANHATOMIRIM                      GR5 - Sul  ICMBio Florianópolis
# 3  APA ANHATOMIRIM                      GR5 - Sul  ICMBio Florianópolis
# 4  APA ANHATOMIRIM                      GR5 - Sul  ICMBio Florianópolis
#
#    Ordem                                           Processo  \
# 0      1                                           Proteção
# ...

# %%
# df_samge7['Ação de Manejo'].unique()

# %% [markdown]
# ## C. MESCLAR BASES

# %%
# df_merged = pd.merge(df1[['id', 'nome']], df2[['id', 'idade']], on='id', how='inner')

# %%
# Definindo coluna como índice

#import pandas as pd
#
## Criando um DataFrame de exemplo
#df = pd.DataFrame({
#    'id': [1, 2, 3, 4],
#    'nome': ['Alice', 'Bob', 'Carlos', 'Diana'],
#    'idade': [25, 30, 22, 29]
#})
#
## Transformando a coluna 'id' em índice
#df.set_index('id', inplace=True)
#
#print(df)

# %%
# Criando um novo DataFrame com colunas selecionadas

# df_selecionado = df[['nome', 'idade']]

# %% [markdown]
# #### Desmatamento

# %%
df_desmatf = df_desmat[['cnuc', 'unidade de conservação', 'área_ha_uc', 2023, 2020,2016,2012,2008, 'TOTAL']]
df_desmatf.rename(columns={'TOTAL': 'Tot_desmat'}, inplace=True)
# df_desmatf.set_index('cnuc', inplace=True)
df_desmatf.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16428\2234815575.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_desmatf.rename(columns={'TOTAL': 'Tot_desmat'}, inplace=True)
#            cnuc                             unidade de conservação  \
# 0  0000.00.0022                              APA do Igarapé Gelado
# 1  0000.00.0268                                     APA do Tapajós
# 2  0000.00.3407                         APA dos Campos de Manicoré
# 3  0000.00.0043  ARIE Projeto Dinâmica Biológica de Fragmento F...
# 4  0000.00.0044                       ARIE Seringal Nova Esperança
#
#      área_ha_uc         2023     2020     2016     2012     2008  \
# 0  2.071467e+04     0.000000    23.75     0.09     0.00   119.53
# 1  2.040336e+06  4879.106948  6963.76  3143.69  2238.81  1648.94
# ...

# %% [markdown]
# #### Identificação

# %%
df_identif = df_samge1[['CNUC', 'UF', 'NGI', "Ano", 'Municípios Abrangidos', 'Plano de Manejo', 'Esfera Administrativa', 'Categoria (Sigla)', 'Grupo (Sigla)', 'Categoria IUCN','Bioma', 'Área Soma Bioma (ha)', 'Ano de Criação', 'Instrumento de Criação']]
df_identif.rename(columns={"Ano": 'AnoSamge_ID', 'CNUC':'cnuc'}, inplace=True)
# df_identif.set_index('CNUC', inplace=True)
df_identif = df_identif[df_identif["AnoSamge_ID"] == 2023]
df_identif = df_identif[df_identif["Esfera Administrativa"] == 'Federal'] 
df_identif.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 329 entries, 0 to 328
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cnuc                    329 non-null    object
#  1   UF                      329 non-null    object
#  2   NGI                     219 non-null    object
#  3   AnoSamge_ID             329 non-null    int64
#  4   Municípios Abrangidos   329 non-null    object
#  5   Plano de Manejo         329 non-null    object
#  6   Esfera Administrativa   329 non-null    object
#  7   Categoria (Sigla)       329 non-null    object
#  8   Grupo (Sigla)           329 non-null    object
#  9   Categoria IUCN          329 non-null    object
#  10  Bioma                   329 non-null    object
#  11  Área Soma Bioma (ha)    329 non-null    float64
#  12  Ano de Criação          329 non-null    int64
#  13  Instrumento de Criação  329 non-null    object
# ...

# %% [markdown]
# #### RV

# %%
df_RV = df_samge2[['CNUC', 'ID RV', 'Tipo do RV', "Ano", 'Situação do RV', 'Origem dos Fatores', 'Fator']]
df_RV.rename(columns={"Ano": 'AnoSamge_RV', 'CNUC':'cnuc'}, inplace=True)
df_RV = df_RV[df_RV["AnoSamge_RV"] == 2023]
# df_RV.set_index('CNUC', inplace=True)
df_RV.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16428\2537854235.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RV.rename(columns={"Ano": 'AnoSamge_RV', 'CNUC':'cnuc'}, inplace=True)
#            cnuc  ID RV               Tipo do RV  AnoSamge_RV Situação do RV  \
# 0  0000.00.0001  78191           Biodiversidade         2023    Intervenção
# 1  0000.00.0001  78190       Histórico-Cultural         2023    Intervenção
# 2  0000.00.0001  78189  Serviços Ecossistêmicos         2023    Intervenção
# 3  0000.00.0001  78188           Biodiversidade         2023    Intervenção
# 4  0000.00.0001  78187           Biodiversidade         2023    Intervenção
#
#    Origem dos Fatores                                              Fator
# ...

# %% [markdown]
# #### RV_ACAO_USO

# %%
df_RV_Acao_Uso = df_samge6[['CNUC', 'ID RV', 'ID Ação', "Processo", 'Ação de Manejo','ID Uso','Uso Genérico', 'Uso Específico', 'Descrição do Uso', "Ano"]]
df_RV_Acao_Uso.rename(columns={"Ano": 'AnoSamge_RVAU'}, inplace=True)
df_RV_Acao_Uso = df_RV_Acao_Uso[df_RV_Acao_Uso["AnoSamge_RVAU"] == 2023]
#df_RV_Acao_Uso.set_index('CNUC', inplace=True)
df_RV_Acao_Uso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21946 entries, 0 to 21945
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CNUC              21946 non-null  object
#  1   ID RV             21946 non-null  int64
#  2   ID Ação           11163 non-null  float64
#  3   Processo          11163 non-null  object
#  4   Ação de Manejo    11163 non-null  object
#  5   ID Uso            10783 non-null  float64
#  6   Uso Genérico      10783 non-null  object
#  7   Uso Específico    10783 non-null  object
#  8   Descrição do Uso  10783 non-null  object
#  9   AnoSamge_RVAU     21946 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 1.8+ MB
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16428\2549985040.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# #### USOS

# %%
df_Usos = df_samge3[['CNUC', 'ID Uso', 'Legalidade', 'Legalidade Marcada', 'Média de Impacto de Uso', 'Desafio Territorial de Gestão', 'Uso por Comunidade Tradicional e/ou Turismo de Base Comunitária?', 'Voluntariado?', "Ano"]]
df_Usos.rename(columns={"Ano": 'AnoSamge_Usos'}, inplace=True)
#df_Usos.set_index('CNUC', inplace=True)
df_Usos.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16428\2483484417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Usos.rename(columns={"Ano": 'AnoSamge_Usos'}, inplace=True)
#            CNUC  ID Uso   Legalidade Legalidade Marcada  \
# 0  0000.00.0001   63004  Incentivado        Incentivado
# 1  0000.00.0001   63006    Permitido        Incentivado
# 2  0000.00.0001   63016    Permitido        Incentivado
# 3  0000.00.0001   63014    Permitido          Permitido
# 4  0000.00.0001   63012    Permitido          Permitido
#
#    Média de Impacto de Uso Desafio Territorial de Gestão  \
# 0                 4.000000                           Não
# 1                 4.000000                           Não
# 2                 2.000000                           Não
# ...

# %% [markdown]
# ### *MESCLASSS*

# %%
#df_merged = pd.merge(df_desmatf, df_identif, on='cnuc', how='outer')
df_merged = pd.merge(df_desmat, df_identif, on='cnuc', how='outer') 
df_merged.drop(['TOTAL', 'AnoSamge_ID', 'Esfera Administrativa', 'Área Soma Bioma (ha)', 'Categoria IUCN', 'Instrumento de Criação','Municípios Abrangidos'], axis=1, inplace=True)
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cnuc                    330 non-null    object
#  1   unidade de conservação  132 non-null    object
#  2   área_ha_uc              132 non-null    float64
#  3   Até 2007                132 non-null    float64
#  4   2008                    132 non-null    float64
#  5   2009                    132 non-null    float64
#  6   2010                    132 non-null    float64
#  7   2011                    132 non-null    float64
#  8   2012                    132 non-null    float64
#  9   2013                    132 non-null    float64
#  10  2014                    132 non-null    float64
#  11  2015                    132 non-null    float64
#  12  2016                    132 non-null    float64
#  13  2017                    132 non-null    float64
# ...

# %%
#df_merged2 = pd.merge(df_merged, df_RV, on='cnuc', how='left')
#df_merged2 = df_merged2.groupby('cnuc')
#df_merged2.head()

# %% [markdown]
# # *Estatística Descritiva*

# %% [markdown]
# ## Aula 2

# %% [markdown]
# ### A2.1. Carregando a amostra e exibindo as variáveis
#
# df.info()
#
# #### Frequência em escala nominal
# df.coluna.value_counts()
#
# #### Frequência em escala ordinal
# df["coluna"].value_counts().sort_index()
#
# #### Frequência em escala intervalar
#
# def faixa(x):
#   try:
#       x = int(x)
#   except:
#       return pd.NA
#
#   if x<1: return "0-1"
#   elif x<2: return "1-2"
#   elif x<3: return "2-3"
#   elif x<4: return "3-4"
#   elif x<5: return "4-5"
#   elif x<6: return "5-6"
#   elif x<7: return "6-7"
#   elif x<8: return "7-8"
#   elif x<9: return "8-9"
#   elif x<10: return "9-10"
#
#   return pd.NA
#
# ideb['faixas'] = ideb.IDEB12_17.apply(faixa);
#
# ideb.faixas.value_counts().sort_index()
#
#
# OU
#
# consumidor.NotaDoConsumidor.value_counts().sort_index()

# %% [markdown]
# ### A2.2 Histograma
